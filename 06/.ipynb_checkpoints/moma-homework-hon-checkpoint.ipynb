# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("moma.csv", encoding="utf-8-sig")

# %%
df[['Title']].head()
# Out:
#                                                Title
# 0  Ferdinandsbrücke Project, Vienna, Austria , El...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...

# %%
df.head(10)
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria , El...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
# 5  The Manhattan Transcripts Project, New York, N...
# 6  The Manhattan Transcripts Project, New York, N...
# 7  The Manhattan Transcripts Project, New York, N...
# 8  The Manhattan Transcripts Project, New York, N...
# 9  The Manhattan Transcripts Project, New York, N...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
# 5           Bernard Tschumi          7056
# 6           Bernard Tschumi          7056
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio', 'Nationality',
#        'BeginDate', 'EndDate', 'Gender', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)'],
#       dtype='object')

# %% [markdown]
# * What are the top 5 artists with the most works?
# * How many artists look like they may still be alive?
# * What are the top 10 largest art works? Can you put that in a pretty chart?
# * Where are the female artists?
# * Which year did the MoMA acquire the most artworks? What about the top ten years? Can you put that in a pretty chart?
# * What are some of the most common media used?
# * What are the most common type of classification? Can you chart that?
# * How many modern artists are French?
# * What is the oldest artwork and who gave it to moma?
# * How many different CreditLines are there? Who is the most generous donor?
# *

# %%
#What are the top 5 artists with the most works?
number_of_artists = df['Artist'].value_counts()
number_of_artists.sort_values(ascending=False).head()
# Out:
# Eugène Atget                5050
# Louise Bourgeois            3275
# Ludwig Mies van der Rohe    2557
# Unknown photographer        1574
# Jean Dubuffet               1435
# Name: Artist, dtype: int64

# %%
df.columns[0] #WEIRD ENCODING
#Title = df.columns[0]
# Out:
# 'Title'

# %%
#How many artists look like they may still be alive?
#From the dataset it looks like artists who are dead look something like 1918 - 1999, but artists who are still alive
#are (born...)
is_alive = df['ArtistBio'].str.contains('born')
has_a_title = df['Title'].notnull()
#if alive_artists == True:
#    print(df[Title])
df[is_alive & has_a_title]
df[(df['Title'].str.contains('born')) & (df['Title'].notnull())]
# Out:
#                                                     Title  \
# 5847                        Ed Osborn, Gitaar Electronica
# 7045                                 Dearborn Observatory
# 7100           Predlohy pro odborne kresleni typograficke
# 7413    Informace pro P. T. reditelstvi mestanskych sk...
# 8704    Dokhlaia luna. Sbornik edinstvennykh futuristo...
# 8904    Zatychka. Sbornik. Velimir Khlebnikov; David, ...
# 9674    Izbornik stikhov s poslesloviem rechiaria. 190...
# 12730          Solntsebunt i rzha. Sbornik stikhov vtoroi
# 13425   Vserossiiskii soiuz poetov. Vtoroi sbornik sti...
# 14276             Epopeia. Literaturnyi sbornik, nos. 1-4
# 14277   Epopeia: literaturnyi sbornik (Epopée: Literar...
# 14725   Biznes. Sbornik literaturnogo tsentra konstruk...
# 15923   Za chto nas b'iut. Vtoroe izdanie sbornika. Ne...
# 15947         Trebnikh troikh. Sbornik stikhov i risunkov
# 16153                 Vesennee kontragenstvo muz. Sbornik
# ...

# %%
#What are the top 10 largest art works? Can you put that in a pretty chart?
#Area of art work = height x width
df['Area'] = df['Height (cm)'] * df['Width (cm)']
big_art = df.sort_values(by=['Area'], ascending=False).head(10)
#big_art.plot(kind='barh')
# df.sort_values(by=['Area'], ascending=False).plot(kind='barh', x=title, y='Area').head(10)
# big_art.plot(kind='barh', x=title, y='Area')

#Why won't it let me use the title? <- Strange characters in Title

# %%
big_art.plot(kind='barh', x='Title', y='Area')

# %%
#What is the heaviest artwork? What is that in pounds?
df.sort_values('Weight (kg)', ascending=False).head(1)
df['Weight (lbs)'] = df['Weight (kg)'] * 2.20462
df
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria , El...
# 1       City of Music, National Superior Conservatory ...
# 2       Villa near Vienna Project, Outside Vienna, Aus...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       Villa, project, outside Vienna, Austria, Exter...
# 5       The Manhattan Transcripts Project, New York, N...
# 6       The Manhattan Transcripts Project, New York, N...
# 7       The Manhattan Transcripts Project, New York, N...
# 8       The Manhattan Transcripts Project, New York, N...
# 9       The Manhattan Transcripts Project, New York, N...
# 10      The Manhattan Transcripts Project, New York, N...
# 11      The Manhattan Transcripts Project, New York, N...
# 12      The Manhattan Transcripts Project, New York, N...
# 13      The Manhattan Transcripts Project, New York, N...
# 14      The Manhattan Transcripts Project, New York, N...
# ...

# %%
#Where are the artists are female?

is_female = df['Gender'].str.contains('(Female)')
is_not_genderless = df['Gender'].notnull()
df[is_female & is_not_genderless]

#Too many () and NA values and I don't know what the unknowns are
# Out:
# /Users/honjingyi/.virtualenvs/data-analysis/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   app.launch_new_instance()
#                                                     Title  \
# 66      Villa dall'Ava, Paris (Saint-Cloud), France , ...
# 151     Slow House Project, North Haven, New York, Pla...
# 152     The Peak Project, Hong Kong, China (Exterior p...
# 154     Egg of Columbus Circle, project, New York, New...
# 161     House, Northern Delaware, Preliminary study of...
# 162     Gordon Wu Hall, Princeton University , Princet...
# 163     Gordon Wu Hall, Princeton University , Princet...
# 164     Lewis Thomas Laboratory for Molecular Biology,...
# 242     Boompjes Tower Slab, project , Rotterdam, The ...
# 295     Parc de la Villette Project, Paris, France, Pl...
# 296            Parc de la Villette project, Paris, France
# ...

# %%
#Which year did the MoMA acquire the most artworks? What about the top ten years? Can you put that in a pretty chart?
#df['DateAcquired']

#I don't know how to do this

# %%
#What is the most common media used?
#df['Medium'].describe()
#How to come up with a list of the number of all the differnt types of media?
df['Medium'].value_counts() #yay!
# Out:
# Gelatin silver print                                                                                                                                                                             13810
# Lithograph                                                                                                                                                                                        7101
# Albumen silver print                                                                                                                                                                              4842
# Lithograph, printed in color                                                                                                                                                                      1942
# ...

# %%
#What are the most common types of classification? Can you chart that?
df['Classification'].value_counts().head(5).plot(kind='hist', legend=False)

#top_class = df.sort_values(by=['Classification'], ascending=False).head(5)
#df.groupby("Classification").plot(kind='hist', legend=False)


#How to put value of value count into a chart?
#How to use groupby? How do I get the top five classifications to show?
